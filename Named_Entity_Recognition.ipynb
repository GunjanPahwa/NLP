# %%
import nltk
print("Downloading missing internal resource 'punkt_tab'...")
nltk.download('punkt_tab')
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sentences='The Eiffel tower was built from 1887 to 1889 by French Engineer Gustav Eiffel, whose company specialized in building metal frameworks and structures.'
"""
Person Eg: Gunjan Pahwa
Place or Location Eg: India
Date Eg: 19-10-2004
Time Eg: 9:30am
Money Eg: 1 million dollar
Organization Eg: iNeuron Private Limited
Percent Eg: 20%, twenty percent
"""
# Out:
# '\nPerson Eg: Gunjan Pahwa\nPlace or Location Eg: India\nDate Eg: 19-10-2004\nTime Eg: 9:30am\nMoney Eg: 1 million dollar\nOrganization Eg: iNeuron Private Limited\nPercent Eg: 20%, twenty percent\n'

# %%
sentences='The Eiffel tower was built from 1887 to 1889 by French Engineer Gustav Eiffel, whose company specialized in building metal frameworks and structures.'

# %%
import nltk
nltk.download('punkt')
words=nltk.word_tokenize(sentences)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
import os

# This lists all paths NLTK searches. The first one is often the custom path.
print("NLTK Search Paths:")
print(nltk.data.path)
# Out:
# NLTK Search Paths:
# ['C:\\Users\\HP/nltk_data', 'c:\\Users\\HP\\anaconda3\\envs\\nlp_fix_env\\nltk_data', 'c:\\Users\\HP\\anaconda3\\envs\\nlp_fix_env\\share\\nltk_data', 'c:\\Users\\HP\\anaconda3\\envs\\nlp_fix_env\\lib\\nltk_data', 'C:\\Users\\HP\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
import nltk
print("Downloading missing language resource...")
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# ...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk

sentences='The Eiffel tower was built from 1887 to 1889 by French Engineer Gustav Eiffel, whose company specialized in building metal frameworks and structures.'

# Tokenize and Tag
print("\nAttempting Final Tokenization and Tagging...")
# NOTE: To be absolutely safe, try calling without the lang parameter first.
words = word_tokenize(sentences) 
tagged_words = nltk.pos_tag(words) 

print("\n--- ✅ SUCCESSFUL TAGGED OUTPUT ---")
print(tagged_words)
# Out:
# Attempting Final Tokenization and Tagging...
#
# --- ✅ SUCCESSFUL TAGGED OUTPUT ---
# [('The', 'DT'), ('Eiffel', 'NNP'), ('tower', 'NN'), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), ('French', 'JJ'), ('Engineer', 'NNP'), ('Gustav', 'NNP'), ('Eiffel', 'NNP'), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')]

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.ne_chunk(tagged_words)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# Tree('S', [('The', 'DT'), Tree('GPE', [('Eiffel', 'NNP')]), ('tower', 'NN'), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), Tree('ORGANIZATION', [('Engineer', 'NNP'), ('Gustav', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])
